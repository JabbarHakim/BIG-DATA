# %%
from pymongo import MongoClient, InsertOne, UpdateOne, DeleteOne

# Establish client connection
client = MongoClient('mongodb://localhost:27017/')
db = client['university_db']
courses_collection = db['courses']

# Bulk insert of courses with student enrollments
operations = [
    InsertOne({'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics'}),
    InsertOne({'course': 'CS 102', 'enrollments': 25, 'department': 'Computer Science'}),
    InsertOne({'course': 'History 201', 'enrollments': 20, 'department': 'History'}),
    InsertOne({'course': 'Physics 202', 'enrollments': 15, 'department': 'Physics'})
]
courses_collection.bulk_write(operations)
print('Courses inserted successfully.')
# Out:
# Courses inserted successfully.

# %%
# Query for courses with enrollments greater than 20
for course in courses_collection.find({'enrollments': {'$gt': 20}}):
    print(course)
# Out:
# {'_id': ObjectId('690c4311d2c1e0d14643a57b'), 'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics'}
# {'_id': ObjectId('690c4311d2c1e0d14643a57c'), 'course': 'CS 102', 'enrollments': 25, 'department': 'Computer Science'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a57f'), 'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a580'), 'course': 'CS 102', 'enrollments': 25, 'department': 'Computer Science'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a583'), 'course': 'Math 202', 'enrollments': 35, 'department': 'Mathematics'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a584'), 'course': 'CS 201', 'enrollments': 22, 'department': 'Computer Science'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a586'), 'course': 'History 301', 'enrollments': 30, 'department': 'History'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a588'), 'course': 'Physics 303', 'enrollments': 28, 'department': 'Physics'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a589'), 'course': 'Chemistry 101', 'enrollments': 40, 'department': 'Chemistry'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a58a'), 'course': 'Biology 110', 'enrollments': 45, 'department': 'Biology'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a58c'), 'course': 'English 200', 'enrollments': 50, 'department': 'English'}
# {'_id': ObjectId('690c4873929d0a87f750fe36'), 'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics'}
# {'_id': ObjectId('690c4873929d0a87f750fe37'), 'course': 'CS 102', 'enrollments': 25, 'department': 'Computer Science'}

# %%
# Query courses in Computer Science or Mathematics departments
for course in courses_collection.find({'department': {'$in': ['Computer Science', 'Mathematics']}}):
    print(course)
# Out:
# {'_id': ObjectId('690c4311d2c1e0d14643a57b'), 'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics'}
# {'_id': ObjectId('690c4311d2c1e0d14643a57c'), 'course': 'CS 102', 'enrollments': 25, 'department': 'Computer Science'}

# %%
# Average enrollment per department using aggregation
pipeline = [
    {'$group': {'_id': '$department', 'average_enrollment': {'$avg': '$enrollments'}}}
]
for result in courses_collection.aggregate(pipeline):
    print(result)
# Out:
# {'_id': 'English', 'average_enrollment': 50.0}
# {'_id': 'Physics', 'average_enrollment': 18.25}
# {'_id': 'Computer Science', 'average_enrollment': 23.0}
# {'_id': 'Mathematics', 'average_enrollment': 31.25}
# {'_id': 'History', 'average_enrollment': 21.0}
# {'_id': 'Chemistry', 'average_enrollment': 40.0}
# {'_id': 'Biology', 'average_enrollment': 45.0}
# {'_id': 'Philosophy', 'average_enrollment': 12.0}

# %%
# Maximum enrollment per department
pipeline = [
    {'$group': {'_id': '$department', 'max_enrollment': {'$max': '$enrollments'}}}
]
for result in courses_collection.aggregate(pipeline):
    print(result)
# Out:
# {'_id': 'English', 'max_enrollment': 50}
# {'_id': 'Physics', 'max_enrollment': 28}
# {'_id': 'Computer Science', 'max_enrollment': 25}
# {'_id': 'Mathematics', 'max_enrollment': 35}
# {'_id': 'History', 'max_enrollment': 30}
# {'_id': 'Chemistry', 'max_enrollment': 40}
# {'_id': 'Biology', 'max_enrollment': 45}
# {'_id': 'Philosophy', 'max_enrollment': 12}

# %%
# Projection to rename fields
pipeline = [
    {'$project': {'course_name': '$course', 'department_name': '$department', 'enrollments': 1}}
]
for result in courses_collection.aggregate(pipeline):
    print(result)
# Out:
# {'_id': ObjectId('690c4311d2c1e0d14643a57b'), 'enrollments': 30, 'course_name': 'Math 101', 'department_name': 'Mathematics'}
# {'_id': ObjectId('690c4311d2c1e0d14643a57c'), 'enrollments': 25, 'course_name': 'CS 102', 'department_name': 'Computer Science'}
# {'_id': ObjectId('690c4311d2c1e0d14643a57d'), 'enrollments': 20, 'course_name': 'History 201', 'department_name': 'History'}
# {'_id': ObjectId('690c4311d2c1e0d14643a57e'), 'enrollments': 15, 'course_name': 'Physics 202', 'department_name': 'Physics'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a57f'), 'enrollments': 30, 'course_name': 'Math 101', 'department_name': 'Mathematics'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a580'), 'enrollments': 25, 'course_name': 'CS 102', 'department_name': 'Computer Science'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a581'), 'enrollments': 20, 'course_name': 'History 201', 'department_name': 'History'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a582'), 'enrollments': 15, 'course_name': 'Physics 202', 'department_name': 'Physics'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a583'), 'enrollments': 35, 'course_name': 'Math 202', 'department_name': 'Mathematics'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a584'), 'enrollments': 22, 'course_name': 'CS 201', 'department_name': 'Computer Science'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a585'), 'enrollments': 18, 'course_name': 'CS 301', 'department_name': 'Computer Science'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a586'), 'enrollments': 30, 'course_name': 'History 301', 'department_name': 'History'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a587'), 'enrollments': 15, 'course_name': 'History 404', 'department_name': 'History'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a588'), 'enrollments': 28, 'course_name': 'Physics 303', 'department_name': 'Physics'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a589'), 'enrollments': 40, 'course_name': 'Chemistry 101', 'department_name': 'Chemistry'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a58a'), 'enrollments': 45, 'course_name': 'Biology 110', 'department_name': 'Biology'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a58b'), 'enrollments': 12, 'course_name': 'Philosophy 101', 'department_name': 'Philosophy'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a58c'), 'enrollments': 50, 'course_name': 'English 200', 'department_name': 'English'}
# {'_id': ObjectId('690c4873929d0a87f750fe36'), 'enrollments': 30, 'course_name': 'Math 101', 'department_name': 'Mathematics'}
# {'_id': ObjectId('690c4873929d0a87f750fe37'), 'enrollments': 25, 'course_name': 'CS 102', 'department_name': 'Computer Science'}
# {'_id': ObjectId('690c4873929d0a87f750fe38'), 'enrollments': 20, 'course_name': 'History 201', 'department_name': 'History'}
# {'_id': ObjectId('690c4873929d0a87f750fe39'), 'enrollments': 15, 'course_name': 'Physics 202', 'department_name': 'Physics'}

# %%
# Adding enrollment category field based on enrollments
pipeline = [
    {'$addFields': {'enrollment_category': {'$cond': {'if': {'$gt': ['$enrollments', 20]}, 'then': 'high', 'else': 'low'}}}}
]
for result in courses_collection.aggregate(pipeline):
    print(result)
# Out:
# {'_id': ObjectId('690c4311d2c1e0d14643a57b'), 'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c4311d2c1e0d14643a57c'), 'course': 'CS 102', 'enrollments': 25, 'department': 'Computer Science', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c4311d2c1e0d14643a57d'), 'course': 'History 201', 'enrollments': 20, 'department': 'History', 'enrollment_category': 'low'}
# {'_id': ObjectId('690c4311d2c1e0d14643a57e'), 'course': 'Physics 202', 'enrollments': 15, 'department': 'Physics', 'enrollment_category': 'low'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a57f'), 'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a580'), 'course': 'CS 102', 'enrollments': 25, 'department': 'Computer Science', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a581'), 'course': 'History 201', 'enrollments': 20, 'department': 'History', 'enrollment_category': 'low'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a582'), 'course': 'Physics 202', 'enrollments': 15, 'department': 'Physics', 'enrollment_category': 'low'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a583'), 'course': 'Math 202', 'enrollments': 35, 'department': 'Mathematics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a584'), 'course': 'CS 201', 'enrollments': 22, 'department': 'Computer Science', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a585'), 'course': 'CS 301', 'enrollments': 18, 'department': 'Computer Science', 'enrollment_category': 'low'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a586'), 'course': 'History 301', 'enrollments': 30, 'department': 'History', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a587'), 'course': 'History 404', 'enrollments': 15, 'department': 'History', 'enrollment_category': 'low'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a588'), 'course': 'Physics 303', 'enrollments': 28, 'department': 'Physics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a589'), 'course': 'Chemistry 101', 'enrollments': 40, 'department': 'Chemistry', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a58a'), 'course': 'Biology 110', 'enrollments': 45, 'department': 'Biology', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a58b'), 'course': 'Philosophy 101', 'enrollments': 12, 'department': 'Philosophy', 'enrollment_category': 'low'}
# {'_id': ObjectId('690c44e0d2c1e0d14643a58c'), 'course': 'English 200', 'enrollments': 50, 'department': 'English', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c4873929d0a87f750fe36'), 'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c4873929d0a87f750fe37'), 'course': 'CS 102', 'enrollments': 25, 'department': 'Computer Science', 'enrollment_category': 'high'}
# {'_id': ObjectId('690c4873929d0a87f750fe38'), 'course': 'History 201', 'enrollments': 20, 'department': 'History', 'enrollment_category': 'low'}
# {'_id': ObjectId('690c4873929d0a87f750fe39'), 'course': 'Physics 202', 'enrollments': 15, 'department': 'Physics', 'enrollment_category': 'low'}

# %%
course_collections = db['courses']

# %%
# Bulk insert of additional courses with student enrollments
operations = [
    InsertOne({'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics'}),
    InsertOne({'course': 'CS 102', 'enrollments': 27, 'department': 'Computer Science'}),
    InsertOne({'course': 'History 201', 'enrollments': 20, 'department': 'History'}),
    InsertOne({'course': 'Physics 202', 'enrollments': 15, 'department': 'Physics'}),
    
    # New courses
    InsertOne({'course': 'Math 202', 'enrollments': 35, 'department': 'Mathematics'}),
    InsertOne({'course': 'CS 201', 'enrollments': 29, 'department': 'Computer Science'}),
    InsertOne({'course': 'CS 301', 'enrollments': 28, 'department': 'Computer Science'}),
    InsertOne({'course': 'History 301', 'enrollments': 30, 'department': 'History'}),
    InsertOne({'course': 'History 404', 'enrollments': 15, 'department': 'History'}),
    InsertOne({'course': 'Physics 303', 'enrollments': 28, 'department': 'Physics'}),
    InsertOne({'course': 'Chemistry 101', 'enrollments': 40, 'department': 'Chemistry'}),
    InsertOne({'course': 'Biology 110', 'enrollments': 45, 'department': 'Biology'}),
    InsertOne({'course': 'Philosophy 101', 'enrollments': 12, 'department': 'Philosophy'}),
    InsertOne({'course': 'English 200', 'enrollments': 50, 'department': 'English'})
]

# Perform bulk insert into the courses collection
course_collections.bulk_write(operations)
print('Courses inserted successfully.')
# Out:
# Courses inserted successfully.

# %%
# Aggregation to get count of courses per department
pipeline =[
    {"$group" : {"_id": "$department", 
                 "courses_count": {"$sum":1}
                }
    }
]

for result in course_collections.aggregate(pipeline):
    print(result)
# Out:
# {'_id': 'Philosophy', 'courses_count': 1}
# {'_id': 'History', 'courses_count': 3}
# {'_id': 'Mathematics', 'courses_count': 2}
# {'_id': 'Computer Science', 'courses_count': 3}
# {'_id': 'Chemistry', 'courses_count': 1}
# {'_id': 'Biology', 'courses_count': 1}
# {'_id': 'Physics', 'courses_count': 2}
# {'_id': 'English', 'courses_count': 1}

# %%
# Aggregation to get courses with Enrollments > 25 in Computer Science
pipeline = [
    {"$match": {"department":"Computer Science","enrollments": {"$gt": 25}}}
    
      
]

for filtering in course_collections.aggregate(pipeline):
    print(filtering)
# Out:
# {'_id': ObjectId('690c503b5164a175b3296909'), 'course': 'CS 102', 'enrollments': 27, 'department': 'Computer Science'}
# {'_id': ObjectId('690c503b5164a175b329690d'), 'course': 'CS 201', 'enrollments': 29, 'department': 'Computer Science'}
# {'_id': ObjectId('690c503b5164a175b329690e'), 'course': 'CS 301', 'enrollments': 28, 'department': 'Computer Science'}

# %%
# Aggregation to get courses with enrollments > 25 in Computer Science
pipeline = [
    # Match documents for "Computer Science" department and enrollments > 25
    {"$match": {
        "department": "Computer Science",
        "enrollments": {"$gt": 25}
        }
    },
    
    # Group by course and department, and get the first enrollment for each group
    {"$group": {"_id":{
                "Course": "$course",
                "Department": "$department"},
                "Enrollments": {"$first": "$enrollments"}  # First enrollment value for each group
               }
    }
]


# Execute aggregation
for filtering in course_collections.aggregate(pipeline):
    print(filtering)
# Out:
# {'_id': {'Course': 'CS 301', 'Department': 'Computer Science'}, 'Enrollments': 28}
# {'_id': {'Course': 'CS 102', 'Department': 'Computer Science'}, 'Enrollments': 27}
# {'_id': {'Course': 'CS 201', 'Department': 'Computer Science'}, 'Enrollments': 29}

# %%
pip install faker
# Out:
# Collecting faker
#   Downloading faker-37.12.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tzdata in /home/hakim/anaconda3/envs/ervira/lib/python3.13/site-packages (from faker) (2025.2)
# Downloading faker-37.12.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 5.3 MB/s  0:00:00m 4.3 MB/s eta 0:00:01
# Installing collected packages: faker
# Successfully installed faker-37.12.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import random
import faker

fake = faker.Faker()
students_collection = db['students']

course_enrollments = [
    {"course": "Math 101", "enrollments": 30},
    {"course": "CS 102", "enrollments": 27},
    {"course": "History 201", "enrollments": 20},
    {"course": "Physics 202", "enrollments": 15},
    {"course": "Math 202", "enrollments": 35},
    {"course": "CS 201", "enrollments": 29},
    {"course": "CS 301", "enrollments": 28},
    {"course": "History 301", "enrollments": 30},
    {"course": "History 404", "enrollments": 15},
    {"course": "Physics 303", "enrollments": 28},
    {"course": "Chemistry 101", "enrollments": 40},
    {"course": "Biology 110", "enrollments": 45},
    {"course": "Philosophy 101", "enrollments": 12},
    {"course": "English 200", "enrollments": 50}
]

students_operations = []

# Generate 5 students for each course
for course in course_enrollments:
    for _ in range(course['enrollments']):  # Generate number of students based on enrollments
        student_name = fake.first_name()
        student_id = random.randint(1000, 9999)  # Random student ID
        students_operations.append(InsertOne({
            'student_id': student_id,
            'name': student_name,
            'course_enrollment': course['enrollments']  # Match to course enrollments
        }))
        
students_collection.bulk_write(students_operations)

print(f"Inserted {len(students_operations)} dummy student records into the students collection.")
# Out:
# Inserted 404 dummy student records into the students collection.

# %%
for i in students_collection.find():
    print(i)
# Out:
# {'_id': ObjectId('690c50645164a175b3296916'), 'student_id': 2073, 'name': 'Michael', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b3296917'), 'student_id': 5905, 'name': 'Amanda', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b3296918'), 'student_id': 8669, 'name': 'Stephanie', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b3296919'), 'student_id': 3227, 'name': 'Mario', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b329691a'), 'student_id': 9045, 'name': 'Jack', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b329691b'), 'student_id': 6340, 'name': 'Courtney', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b329691c'), 'student_id': 4130, 'name': 'Joseph', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b329691d'), 'student_id': 3738, 'name': 'Jose', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b329691e'), 'student_id': 9682, 'name': 'Jeremy', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b329691f'), 'student_id': 5732, 'name': 'Jennifer', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b3296920'), 'student_id': 6176, 'name': 'Alexandria', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b3296921'), 'student_id': 8432, 'name': 'Penny', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b3296922'), 'student_id': 3948, 'name': 'Ray', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b3296923'), 'student_id': 2207, 'name': 'Tonya', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b3296924'), 'student_id': 2410, 'name': 'Andrew', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b3296925'), 'student_id': 2576, 'name': 'Alan', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b3296926'), 'student_id': 7057, 'name': 'Shawn', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b3296927'), 'student_id': 2320, 'name': 'Juan', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b3296928'), 'student_id': 3755, 'name': 'Amy', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b3296929'), 'student_id': 9502, 'name': 'Terri', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b329692a'), 'student_id': 2349, 'name': 'Andrew', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b329692b'), 'student_id': 8708, 'name': 'Kimberly', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b329692c'), 'student_id': 8123, 'name': 'Carrie', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b329692d'), 'student_id': 4874, 'name': 'Michelle', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b329692e'), 'student_id': 8735, 'name': 'Autumn', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b329692f'), 'student_id': 6183, 'name': 'Laura', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b3296930'), 'student_id': 6046, 'name': 'Tammy', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b3296931'), 'student_id': 7009, 'name': 'Shannon', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b3296932'), 'student_id': 9640, 'name': 'Elizabeth', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b3296933'), 'student_id': 5760, 'name': 'Joseph', 'course_enrollment': 30}
# {'_id': ObjectId('690c50645164a175b3296934'), 'student_id': 7799, 'name': 'Crystal', 'course_enrollment': 27}
# {'_id': ObjectId('690c50645164a175b3296935'), 'student_id': 8569, 'name': 'Sylvia', 'course_enrollment': 27}
# {'_id': ObjectId('690c50645164a175b3296936'), 'student_id': 1624, 'name': 'Alicia', 'course_enrollment': 27}
# {'_id': ObjectId('690c50645164a175b3296937'), 'student_id': 3935, 'name': 'Hunter', 'course_enrollment': 27}
# {'_id': ObjectId('690c50645164a175b3296938'), 'student_id': 5186, 'name': 'Debra', 'course_enrollment': 27}
# {'_id': ObjectId('690c50645164a175b3296939'), 'student_id': 6051, 'name': 'John', 'course_enrollment': 27}
# {'_id': ObjectId('690c50645164a175b329693a'), 'student_id': 5640, 'name': 'Ross', 'course_enrollment': 27}
# {'_id': ObjectId('690c50645164a175b329693b'), 'student_id': 9027, 'name': 'Benjamin', 'course_enrollment': 27}
# {'_id': ObjectId('690c50645164a175b329693c'), 'student_id': 7127, 'name': 'Lindsay', 'course_enrollment': 27}
# {'_id': ObjectId('690c50645164a175b329693d'), 'student_id': 2733, 'name': 'Dennis', 'course_enrollment': 27}
# {'_id': ObjectId('690c50645164a175b329693e'), 'student_id': 7222, 'name': 'Michele', 'course_enrollment': 27}
# {'_id': ObjectId('690c50645164a175b329693f'), 'student_id': 1752, 'name': 'Devin', 'course_enrollment': 27}
# {'_id': ObjectId('690c50645164a175b3296940'), 'student_id': 9415, 'name': 'Adam', 'course_enrollment': 27}
# {'_id': ObjectId('690c50645164a175b3296941'), 'student_id': 4311, 'name': 'Taylor', 'course_enrollment': 27}
# {'_id': ObjectId('690c50645164a175b3296942'), 'student_id': 1361, 'name': 'Mark', 'course_enrollment': 27}
# {'_id': ObjectId('690c50645164a175b3296943'), 'student_id': 4274, 'name': 'Joanna', 'course_enrollment': 27}
# {'_id': ObjectId('690c50645164a175b3296944'), 'student_id': 8545, 'name': 'Anthony', 'course_enrollment': 27}
# {'_id': ObjectId('690c50645164a175b3296945'), 'student_id': 6486, 'name': 'Michael', 'course_enrollment': 27}
# {'_id': ObjectId('690c50645164a175b3296946'), 'student_id': 9884, 'name': 'Michael', 'course_enrollment': 27}
# {'_id': ObjectId('690c50645164a175b3296947'), 'student_id': 9622, 'name': 'Elizabeth', 'course_enrollment': 27}
# {'_id': ObjectId('690c50645164a175b3296948'), 'student_id': 5052, 'name': 'Brandy', 'course_enrollment': 27}
# {'_id': ObjectId('690c50645164a175b3296949'), 'student_id': 1508, 'name': 'Jennifer', 'course_enrollment': 27}
# {'_id': ObjectId('690c50645164a175b329694a'), 'student_id': 8038, 'name': 'James', 'course_enrollment': 27}
# {'_id': ObjectId('690c50645164a175b329694b'), 'student_id': 4584, 'name': 'Katherine', 'course_enrollment': 27}
# {'_id': ObjectId('690c50645164a175b329
 'course_enrollment': 50}
# {'_id': ObjectId('690c50645164a175b3296aa8'), 'student_id': 6416, 'name': 'Natasha', 'course_enrollment': 50}
# {'_id': ObjectId('690c50645164a175b3296aa9'), 'student_id': 5949, 'name': 'Sarah', 'course_enrollment': 50}

# %%
# Define the aggregation pipeline to join courses with students
pipeline = [
    {
        "$lookup": {
            "from": "students",  # The students collection
            "localField": "enrollments",  # The field in courses to match
            "foreignField": "course_enrollment",  # The field in students to match
            "as": "students"  # The name of the array that will hold the matched student documents
        }
    },
    {
        "$unwind": {
            "path": "$students",  # Unwind the 'students' array to get one document per match
            "preserveNullAndEmptyArrays": True  # If no match is found, include the course with null student data
        }
    },
    {
        "$project": {
            "_id": 0,  # Optionally exclude the _id field
            "course": 1,
            "department": 1,
            "enrollments": 1,
            "student_name": "$students.name",  # Assuming `name` is a field in the students collection
            "student_id": "$students.student_id"  # Assuming `student_id` is a field in the students collection
        }
    }
]

# Execute the aggregation pipeline
for filtering in course_collections.aggregate(pipeline):
    print(filtering)
# Out:
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Michael', 'student_id': 2073}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Amanda', 'student_id': 5905}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Stephanie', 'student_id': 8669}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Mario', 'student_id': 3227}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Jack', 'student_id': 9045}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Courtney', 'student_id': 6340}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Joseph', 'student_id': 4130}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Jose', 'student_id': 3738}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Jeremy', 'student_id': 9682}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Jennifer', 'student_id': 5732}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Alexandria', 'student_id': 6176}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Penny', 'student_id': 8432}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Ray', 'student_id': 3948}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Tonya', 'student_id': 2207}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Andrew', 'student_id': 2410}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Alan', 'student_id': 2576}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Shawn', 'student_id': 7057}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Juan', 'student_id': 2320}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Amy', 'student_id': 3755}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Terri', 'student_id': 9502}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Andrew', 'student_id': 2349}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Kimberly', 'student_id': 8708}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Carrie', 'student_id': 8123}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Michelle', 'student_id': 4874}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Autumn', 'student_id': 8735}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Laura', 'student_id': 6183}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Tammy', 'student_id': 6046}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Shannon', 'student_id': 7009}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Elizabeth', 'student_id': 9640}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Joseph', 'student_id': 5760}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Lisa', 'student_id': 5941}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Nichole', 'student_id': 1261}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Leroy', 'student_id': 7721}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Nicole', 'student_id': 2685}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'James', 'student_id': 9068}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Rachel', 'student_id': 9708}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Samuel', 'student_id': 3829}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Michelle', 'student_id': 1648}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Jill', 'student_id': 2624}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Ian', 'student_id': 8183}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Carla', 'student_id': 1452}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'James', 'student_id': 3815}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Brandy', 'student_id': 7578}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'John', 'student_id': 5055}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Andrea', 'student_id': 8503}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Steven', 'student_id': 3642}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Jason', 'student_id': 1283}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Erika', 'student_id': 3869}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Charles', 'student_id': 9734}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Kenneth', 'student_id': 6689}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Jennifer', 'student_id': 4259}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Jessica', 'student_id': 5681}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Joseph', 'student_id': 2480}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Lisa', 'student_id': 4534}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Charles', 'student_id': 1541}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Jennifer', 'student_id': 1640}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Rose', 'student_id': 9075}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Kathleen', 'student_id': 3055}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Mckenzie', 'student_id': 8150}
# {'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'student_name': 'Travis', 'student_id': 4412}
# {'course': 'CS 102', 'enrollments': 27, 'department': 'Computer Science', 'student_name': 'Crystal', 'student_id': 7799}
# {'course': 'CS 102', 'enrollments': 27, 'department': 'Computer Science', 'student_name': 'Sylvia', 'student_id': 8569}
# {'course': 'CS 102', 'enrollments': 27, 'department': 'Computer Science', 'student_name': 'Alicia', 'student_id': 1624}
# {'course': 'CS 102', 'enrollments': 27, 'department': 'Computer Science', 'student_name': 'Hunter', 'student_id': 3935}
# {'course': 'CS 102', 'enrollments': 27, 'department': 'Computer Science', 'student_name': 'Debra', 'student_id': 5186}
# {'course': 'CS 102', 'enrollments': 27, 'department': 'Computer Science', 'student_name': 'John', 'student_id': 6051}
# {'course': 'CS 102', 'enrollments': 27, 'department': 'Computer Science', 'student_name': 'Ross', 'student_id': 5640}
# {'course': 'CS 102', 'enrollments': 27, 'department': 'Computer Science', 'student_name': 'Benjamin', 'student_id': 9027}
# {'course': 'CS 102', 'enrollments': 27, 'department': 'Computer Science', 'student_name': 'Lindsay', 'student_id': 7127}
# {'course': 'CS 102', 'enrollments': 27, 'department': 'Computer Science', 'student_name': 'Dennis', 'student_id': 2733}
# {'course': 'CS 102', 'enrollments': 27, 'department': 'Computer Science', 'student_name': 'Michele', 'student_id': 7222}
# {'course': 'CS 102', 'enrollments': 27, 'department': 'Computer Science', 'student_name': 'Devin', 'student_id': 1752}
# {'course': 'CS 102', 'enrollments': 27, 'department': 'Computer Science', 'student_name': 'Adam', 'student_id': 9415}
# {'course': 'CS 102', 'enrollments': 27, 'department': 'Computer Science', 'student_name': 'Taylor', 'student_id': 4311}
# {'course': 'CS 102', 'enrollments': 27, 'department': 'Computer Science', 'student_name': '